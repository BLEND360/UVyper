# %%
from my_library.algorithms.dbscan import dbscan as dbsc

# %%
db = dbsc.dbs('samdata_preprocessed.csv')

# %%
db.get_shape()
# Out:
# (10000, 55)

# %%
eps = db.get_eps(db.nearestneigh(100))

# %%
eps
# Out:
# 8.520570302914452

# %%
clusters = db.dbscan(0.1,percent=5)

# %%
db.scatter_plot(db.pca(clusters))

# %%
db.get_cluster_sizes(clusters)
# Out:
# 0    10000
# dtype: int64

# %%
db.get_cluster_centers(clusters)
# Out:
#    Unnamed: 0  spclty_visit_cnt_processed  ucc_mcable_visit_count_processed  \
# 0      4999.5               -1.989831e-15                     -4.958589e-16
#
#    srv_copay_amt_processed  aetna_num_children_modif_processed  \
# 0             4.026113e-16                        1.335734e-14
#
#    strat_score_value_processed  ucc_visit_cnt_processed  \
# 0                 3.523565e-15            -2.402101e-15
#
#    first_pulse_processed  pcp_visit_cnt_processed  age_nbr_processed  \
# 0          -1.301248e-15             1.863154e-15       3.872014e-16
#
#    op_rehab_visit_cnt_processed  final_future_tenure_processed  \
# 0                  1.367295e-15                   1.109278e-16
#
#    hosop_lab_visit_cnt_processed  income_processed  \
# 0                  -7.976875e-15     -3.672396e-16
#
#    hosop_rad_visit_cnt_processed  op_rehab_allowed_amt_processed  \
# 0                  -2.090772e-16                    5.812295e-15
#
# ...

# %%
db.get_davies_bouldin_score(clusters)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 db.get_davies_bouldin_score(clusters)
#
# File C:\r\p2\my_library\algorithms\dbscan\dbscan.py:150, in dbs.get_davies_bouldin_score(self, clusters)
#     144 def get_davies_bouldin_score(self, clusters):
#     145     """
#     146     Method to get the davies bouldin score
#     147     :param clusters: ndarray - cluster labels
#     148     :return: float - davies bouldin score
#     149     """
# --> 150     return davies_bouldin_score(self.df, clusters)
#
# File ~\anaconda3\envs\vyp\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:344, in davies_bouldin_score(X, labels)
#     342 n_samples, _ = X.shape
#     343 n_labels = len(le.classes_)
# --> 344 check_number_of_labels(n_labels, n_samples)
#     346 intra_dists = np.zeros(n_labels)
# ...

# %%
db.get_silhouette_score(clusters)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 db.get_silhouette_score(clusters)
#
# File C:\r\p2\my_library\algorithms\dbscan\dbscan.py:142, in dbs.get_silhouette_score(self, clusters)
#     136 def get_silhouette_score(self, clusters):
#     137     """
#     138     Method to get the silhouette score
#     139     :param clusters: ndarray - cluster labels
#     140     :return: float - silhouette score
#     141     """
# --> 142     return silhouette_score(self.df, clusters)
#
# File ~\anaconda3\envs\vyp\lib\site-packages\sklearn\utils\validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
# ...
