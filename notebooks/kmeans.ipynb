# %%
from my_library.algorithms.k_means import k_means

# %%
kmeans = k_means.Kmeans('cvs_hcb_member_profiling_preprocessed.csv')

# %%
k_n=kmeans.elbow(2,10,)

# %%
clus = kmeans.kmeans(k_n, 1, kmeans.get_data().shape[0])

# %%
pca = kmeans.pca(clus)

# %%
kmeans.scatter_plot(pca)

# %%
kmeans.get_cluster_sizes(clus)
# Out:
# 0    2510
# 1    2496
# 2    2504
# 3    2490
# dtype: int64

# %%
kmeans.get_cluster_centers(clus)
# Out:
#    Unnamed: 0  spclty_visit_cnt_processed  ucc_mcable_visit_count_processed  \
# 0      8744.5                   -0.285230                          0.078587
# 1      3737.5                    0.362088                         -0.108395
# 2      6237.5                   -0.162987                          0.049595
# 3      1244.5                    0.088464                         -0.020436
#
#    srv_copay_amt_processed  aetna_num_children_modif_processed  \
# 0                -0.228375                            0.962101
# 1                 0.372821                           -0.547606
# 2                -0.141441                           -0.331894
# 3                -0.001274                           -0.087144
#
#    strat_score_value_processed  ucc_visit_cnt_processed  \
# 0                    -0.746711                 0.067040
# 1                     0.730737                -0.112816
# 2                    -0.316500                 0.035526
# ...

# %%
kmeans.get_davies_bouldin_score(clus)
# Out:
# 0.5000869183020991

# %%
kmeans.get_silhouette_score(clus)
# Out:
# 0.5716847642719797
