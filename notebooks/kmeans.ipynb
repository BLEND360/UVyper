# %%
from my_library.algorithms.k_means import k_means

# %%
kmeans = k_means.Kmeans('csv_hcb_member_profiling_preprocessed.csv')

# %%
k_n = kmeans.elbow(2, 10, )

# %%
clus = kmeans.kmeans(k_n, 1, 100, 0.3)

# %%
pca = kmeans.pca(clus)

# %%
kmeans.scatter_plot(pca)

# %%
kmeans.get_cluster_distribution(clus)
# Out:
#    cluster  count  percentage
# 0        0   2549       25.49
# 1        1   2490       24.90
# 2        2   2505       25.05
# 3        3   2456       24.56

# %%
kmeans.get_cluster_centers(clus)
# Out:
#    Unnamed: 0  spclty_visit_cnt_processed  ucc_mcable_visit_count_processed  \
# 0      8725.0                   -0.277866                          0.078426
# 1      1244.5                    0.088464                         -0.020436
# 2      3742.0                    0.359709                         -0.108137
# 3      6222.5                   -0.168187                          0.049617
#
#    srv_copay_amt_processed  aetna_num_children_modif_processed  \
# 0                -0.224070                            0.947850
# 1                -0.001274                           -0.087144
# 2                 0.370186                           -0.546977
# 3                -0.143726                           -0.337502
#
#    strat_score_value_processed  ucc_visit_cnt_processed  \
# 0                    -0.728920                 0.064887
# 1                     0.338490                 0.009784
# 2                     0.730642                -0.112751
# 3                    -0.331873                 0.037737
#
#    first_pulse_processed  pcp_visit_cnt_processed  age_nbr_processed  \
# 0              -0.568735                -0.087276          -1.239659
# 1               0.308114                -0.024261           0.349585
# 2               0.694252                 0.380135           0.849018
# 3              -0.430212                -0.272542           0.066219
#
#    op_rehab_visit_cnt_processed  final_future_tenure_processed  \
# 0                      0.359559                      -0.204721
# 1                     -0.082339                      -0.047910
# 2                     -0.064782                       0.225208
# 3                     -0.223620                       0.031345
#
#    hosop_lab_visit_cnt_processed  income_processed  \
# 0                      -0.232532         -0.061255
# 1                       0.041745          0.182195
# 2                       0.311756         -0.107508
# 3                      -0.118961         -0.011490
#
#    hosop_rad_visit_cnt_processed  op_rehab_allowed_amt_processed  \
# 0                      -0.282783                        0.445611
# 1                       0.078834                       -0.129998
# 2                       0.310437                       -0.129345
# 3                      -0.103064                       -0.198761
#
#    final_total_tenure_processed  medical_allowed_pmpm_processed  \
# 0                     -0.104147                       -0.189554
# 1                      0.063417                        0.090529
# 2                      0.186250                        0.245695
# 3                     -0.146170                       -0.145647
#
#    rx_mths_processed  complex_chronic_common_flag_processed  \
# 0          -0.128669                               0.391972
# 1          -0.132291                              -0.623766
# 2           0.261731                              -0.259864
# 3           0.000711                               0.490635
#
#    relationship_processed  active_medical_ind_ind  hyc_missing_ind   hyc_ind  \
# 0               -0.820628                0.034143        -0.068437 -0.483622
# 1                1.226870                0.068874         0.551522 -0.032072
# 2               -0.071237               -0.080318        -0.453371  0.965616
# 3               -0.319494               -0.023343        -0.025712 -0.450430
#
#    a2020_rx_ind_ind  cvs_rx_inrange_ind_ind  marital_ind  ctd_missing_ind  \
# 0         -0.129779               -0.071710    -0.316194        -0.068437
# 1         -0.132428                0.450115    -0.243869         0.551522
# 2          0.259757               -0.334305     0.161516        -0.453371
# 3          0.004015               -0.040946     0.410674        -0.025712
#
#    dep_missing_ind  alg_missing_ind  active_dental_ind_ind  \
# 0        -0.068437        -0.068437               0.123540
# 1         0.551522         0.551522               0.005275
# 2        -0.453371        -0.453371              -0.134427
# 3        -0.025712        -0.025712               0.003543
#
#    cvs_mc_inrange_ind_ind  a2020_medicare_ind_ind  high_pulse_missing_ind  \
# 0                0.091554               -0.426653               -0.068437
# 1               -0.224602               -0.269771                0.551522
# 2                0.108524                0.830844               -0.453371
# 3                0.022001               -0.131106               -0.025712
#
#    high_pulse_ind  active_pharmacy_ind_ind  active_medicare_ind_ind  \
# 0       -0.234928                -0.220117                -0.398136
# 1        0.266408                -0.163349                -0.230177
# 2        0.326624                 0.465854                 0.764570
# 3       -0.359413                -0.081086                -0.133249
#
#    hyp_missing_ind   hyp_ind  cvs_hh_inrange_ind_ind  dia_missing_ind  \
# 0        -0.068437 -0.499193               -0.107756        -0.068437
# 1         0.551522 -0.017133                0.288604         0.551522
# 2        -0.453371  0.985384               -0.148298        -0.453371
# 3        -0.025712 -0.469578               -0.029506        -0.025712
#
#    a2020_dental_ind_ind  lbp_missing_ind  obe_missing_ind  anx_missing_ind  \
# 0              0.007164        -0.068437        -0.068437        -0.068437
# 1             -0.085117         0.551522         0.551522         0.551522
# 2              0.092015        -0.453371        -0.453371        -0.453371
# 3             -0.014991        -0.025712        -0.025712        -0.025712
#
#    ngd_missing_ind   ngd_ind  pcp_flag_ind  gender_cd_ind  urbsubr_R  \
# 0        -0.068437 -0.257519     -0.086379       0.028229   0.032716
# 1         0.551522  0.003354      0.218127      -0.132384  -0.000986
# 2        -0.453371  0.462550     -0.515176       0.015259   0.089250
# 3        -0.025712 -0.207908      0.393958       0.089356  -0.123986
#
#    urbsubr_S  urbsubr_U   lob_CFI   lob_CSI    lob_ME  cluster
# 0   0.038451  -0.068612 -0.006182  0.349719 -0.426490        0
# 1   0.036242  -0.031865  0.092724  0.150681 -0.269566        1
# 2  -0.009002  -0.083835 -0.099426 -0.600524  0.831342        2
# 3  -0.067469   0.189024  0.013819  0.096777 -0.131992        3

# %%
kmeans.get_davies_bouldin_score(clus)
# Out:
# 0.5000880825757081

# %%
kmeans.get_silhouette_score(clus)
# Out:
# 0.571564852606445

# %%
kmeans.get_scores(clus)
# Out:
#    silhouette_score  davies_bouldin_score
# 0          0.571565              0.500088
